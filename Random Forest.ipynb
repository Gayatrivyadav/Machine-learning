# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline

# %%
dataset = pd.read_csv("C:/Users/Gayatri/Documents/Iris.csv")

# %%
dataset.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
x = dataset.drop(['Id','Species'], axis="columns")

# %%
x
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
y = dataset["Species"]
y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
 
# Creating a instance of label Encoder.
le = LabelEncoder()
 
# Using .fit_transform function to fit label
# encoder and return encoded label
dataset["Species"] = le.fit_transform(dataset['Species'])

# %%
dataset.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier  
clr= RandomForestClassifier(n_estimators= 10, criterion="entropy")  
clr.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
#Predicting the test set result  
y_pred= clr.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix  
cm= confusion_matrix(y_test, y_pred)

# %%
# rf = RandomForestClassifier(random_state=42, n_jobs=-1)
# params = {
#     'max_depth': [2,3,5,10,20],
#     'min_samples_leaf': [5,10,20,50,100,200],
#     'n_estimators': [10,25,30,50,100,200]
# }

# %%
classifier.estimators_[0]
# Out:
# DecisionTreeClassifier(criterion='entropy', max_features='sqrt',
#                        random_state=1518413696)

# %%
# from sklearn.model_selection import GridSearchCV
# # Instantiate the grid search model
# grid_search = GridSearchCV(estimator=rf,
#                            param_grid=params,
#                            cv = 4,
#                            n_jobs=-1, verbose=1, scoring="accuracy")

# %%
# %%time
# grid_search.fit(x_train, y_train)""

# %%
plt.figure(figsize = (5,10))
tree.plot_tree(classifier.estimators_[1],filled = True)
# Out:
# [Text(0.34615384615384615, 0.9166666666666666, 'x[3] <= 0.75\nentropy = 1.563\nsamples = 80\nvalue = [34, 50, 36]'),
#  Text(0.2692307692307692, 0.75, 'entropy = 0.0\nsamples = 27\nvalue = [34, 0, 0]'),
#  Text(0.4230769230769231, 0.75, 'x[0] <= 5.85\nentropy = 0.981\nsamples = 53\nvalue = [0, 50, 36]'),
#  Text(0.15384615384615385, 0.5833333333333334, 'x[0] <= 5.75\nentropy = 0.183\nsamples = 19\nvalue = [0, 35, 1]'),
#  Text(0.07692307692307693, 0.4166666666666667, 'entropy = 0.0\nsamples = 15\nvalue = [0, 31, 0]'),
#  Text(0.23076923076923078, 0.4166666666666667, 'x[2] <= 4.6\nentropy = 0.722\nsamples = 4\nvalue = [0, 4, 1]'),
#  Text(0.15384615384615385, 0.25, 'entropy = 0.0\nsamples = 3\nvalue = [0, 4, 0]'),
#  Text(0.3076923076923077, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6923076923076923, 0.5833333333333334, 'x[3] <= 1.75\nentropy = 0.881\nsamples = 34\nvalue = [0, 15, 35]'),
#  Text(0.5384615384615384, 0.4166666666666667, 'x[2] <= 5.45\nentropy = 0.353\nsamples = 11\nvalue = [0, 14, 1]'),
#  Text(0.46153846153846156, 0.25, 'entropy = 0.0\nsamples = 10\nvalue = [0, 14, 0]'),
#  Text(0.6153846153846154, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8461538461538461, 0.4166666666666667, 'x[0] <= 6.05\nentropy = 0.187\nsamples = 23\nvalue = [0, 1, 34]'),
#  Text(0.7692307692307693, 0.25, 'x[2] <= 4.95\nentropy = 0.918\nsamples = 2\nvalue = [0, 1, 2]'),
#  Text(0.6923076923076923, 0.08333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8461538461538461, 0.08333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 2]'),
#  Text(0.9230769230769231, 0.25, 'entropy = 0.0\nsamples = 21\nvalue = [0, 0, 32]')]

# %%
for i in range(len(classifier.estimators_)):
  tree.plot_tree(classifier.estimators_[i],filled = True)
  plt.show()
